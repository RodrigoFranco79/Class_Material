# %% [markdown]
# # Activites List
# <b>Important: for Activity 1, Activity 2 and  Activity 3 , please use the files [file1.csv](./Data/file1.csv), [file2.csv](./Data/file2.csv) and [file3.csv](./Data/file3.csv) from the [Data](./Data) folder.</b>
# ### Activity 1 (Monday)
#
# - Aggregate data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
# - Standardizing header names
# - Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
# - clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - Removing duplicates

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

# %%
    file1 = pd.read_csv('Data/file1.csv')
    file2 = pd.read_csv('Data/file2.csv')
    file3 = pd.read_csv('Data/file3.csv')

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
def rename_columns(hk_df):
    file3.rename(columns={'State':'ST','Gender':'GENDER'}, inplace=True )
    return file3

# %%
rename_columns(file3)
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file3
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
auto_data=pd.concat([file1,file2,file3], axis=0)
auto_data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#### Standardizing header names
def lower_case_auto_data(auto_data):
    auto_data.columns=[i.lower() for i in auto_data.columns]
    return auto_data
lower_case_auto_data(auto_data)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
auto_data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#### Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
def drop_columns(auto_data):
    auto_data.drop(columns=["customer"], inplace=True)
    return auto_data

# %%
drop_columns(auto_data)
# Out:
#               st gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data.head()
# Out:
#            st gender             education customer lifetime value   income  \
# 0  Washington    NaN                Master                     NaN      0.0
# 1     Arizona      F              Bachelor              697953.59%      0.0
# 2      Nevada      F              Bachelor             1288743.17%  48767.0
# 3  California      M              Bachelor              764586.18%      0.0
# 4  Washington      M  High School or Below              536307.65%  36357.0
#
#    monthly premium auto number of open complaints     policy type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# ...

# %%
list(auto_data.columns)
# Out:
# ['st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
### Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
type
auto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
auto_data.columns
# Out:
# Index(['st', 'gender', 'education', 'customer lifetime value', 'income',
#        'monthly premium auto', 'number of open complaints', 'policy type',
#        'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
auto_data['customer lifetime value'] =auto_data['customer lifetime value'].apply(lambda x: float (x.strip('%'))/100 if isinstance(x,str) else x)

# %%
auto_data
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['customer lifetime value']
# Out:
# 0                NaN
# 1        6979.535900
# 2       12887.431700
# 3        7645.861800
# 4        5363.076500
#             ...
# 7065    23405.987980
# 7066     3096.511217
# 7067     8163.890428
# 7068     7524.442436
# 7069     2611.836866
# Name: customer lifetime value, Length: 12074, dtype: float64

# %%
#### clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.

# %%
auto_data['number of open complaints'] =auto_data['number of open complaints'].apply(lambda x: x.split('/')[1] if isinstance(x,str) else x)

# %%
auto_data
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
#### Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
auto_data.st.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
auto_data.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
auto_data['gender']=auto_data['gender'].replace(['Femal', 'Male'],['F','M'])
auto_data
# Out:
#               st gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['st']=auto_data['st'].replace(['NaN','Arizona','Washington','California','Nevada'],['u','AZ','WA','CA','NV'])
auto_data
# Out:
#       st gender             education  customer lifetime value   income  \
# 0     WA    NaN                Master                      NaN      0.0
# 1     AZ      F              Bachelor              6979.535900      0.0
# 2     NV      F              Bachelor             12887.431700  48767.0
# 3     CA      M              Bachelor              7645.861800      0.0
# 4     WA      M  High School or Below              5363.076500  36357.0
# ...   ..    ...                   ...                      ...      ...
# 7065  CA      M              Bachelor             23405.987980  71941.0
# 7066  CA      F               College              3096.511217  21604.0
# 7067  CA      M              Bachelor              8163.890428      0.0
# 7068  CA      M               College              7524.442436  21941.0
# 7069  CA      M               College              2611.836866      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['gender']=auto_data['gender'].fillna(value="U")
auto_data
# Out:
#       st gender             education  customer lifetime value   income  \
# 0     WA      U                Master                      NaN      0.0
# 1     AZ      F              Bachelor              6979.535900      0.0
# 2     NV      F              Bachelor             12887.431700  48767.0
# 3     CA      M              Bachelor              7645.861800      0.0
# 4     WA      M  High School or Below              5363.076500  36357.0
# ...   ..    ...                   ...                      ...      ...
# 7065  CA      M              Bachelor             23405.987980  71941.0
# 7066  CA      F               College              3096.511217  21604.0
# 7067  CA      M              Bachelor              8163.890428      0.0
# 7068  CA      M               College              7524.442436  21941.0
# 7069  CA      M               College              2611.836866      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['customer lifetime value']=auto_data['customer lifetime value'].astype('float64')
auto_data
# Out:
#       st gender             education  customer lifetime value   income  \
# 0     WA      U                Master                      NaN      0.0
# 1     AZ      F              Bachelor              6979.535900      0.0
# 2     NV      F              Bachelor             12887.431700  48767.0
# 3     CA      M              Bachelor              7645.861800      0.0
# 4     WA      M  High School or Below              5363.076500  36357.0
# ...   ..    ...                   ...                      ...      ...
# 7065  CA      M              Bachelor             23405.987980  71941.0
# 7066  CA      F               College              3096.511217  21604.0
# 7067  CA      M              Bachelor              8163.890428      0.0
# 7068  CA      M               College              7524.442436  21941.0
# 7069  CA      M               College              2611.836866      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['customer lifetime value'].unique()
# Out:
# array([         nan,  6979.5359  , 12887.4317  , ...,  8163.890428,
#         7524.442436,  2611.836866])

# %%
auto_data['customer lifetime value']=auto_data['customer lifetime value'].fillna(auto_data['customer lifetime value'].mean())
auto_data
# Out:
#       st gender             education  customer lifetime value   income  \
# 0     WA      U                Master              7977.057704      0.0
# 1     AZ      F              Bachelor              6979.535900      0.0
# 2     NV      F              Bachelor             12887.431700  48767.0
# 3     CA      M              Bachelor              7645.861800      0.0
# 4     WA      M  High School or Below              5363.076500  36357.0
# ...   ..    ...                   ...                      ...      ...
# 7065  CA      M              Bachelor             23405.987980  71941.0
# 7066  CA      F               College              3096.511217  21604.0
# 7067  CA      M              Bachelor              8163.890428      0.0
# 7068  CA      M               College              7524.442436  21941.0
# 7069  CA      M               College              2611.836866      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# ...

# %%
auto_data['monthly premium auto'].unique()
# Out:
# array([ 1000.,    94.,   108.,   106.,    68.,    69.,    67.,   101.,
#           71.,    93.,   110.,    70.,    64.,    72.,    74.,    79.,
#           73.,    61.,   111.,    80.,    63.,   237.,    65.,   130.,
#           62.,   117.,    91.,    90.,    66.,    99.,   103., 35354.,
#          172.,    92.,   104.,   113.,   124.,   105.,   100.,   112.,
#           97.,    95.,   102.,    96.,   186.,    77.,    76.,   119.,
#           87.,   109.,   107.,    88.,    85.,  6464.,   133.,    86.,
#           78.,    89.,   192.,   118.,   140.,   127.,   126.,    82.,
#          115.,   217.,   114.,   138.,    81.,   255.,   150.,   123.,
#          116.,   190.,    98.,   159.,    84.,    83.,   152.,   136.,
#          245.,   135.,  1005.,   225.,   132.,   153.,   121.,   139.,
#          154.,   161.,   156.,   171.,   244.,   183.,   176.,   230.,
#          129.,   177.,   181.,   196.,   131.,   276.,   253.,   137.,
# ...

# %%
auto_data['education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
auto_data['income'].unique()
# Out:
# array([    0., 48767., 36357., ..., 66367., 71941., 21941.])

# %%
income_mean = auto_data["income"].mean()
print(income_mean)
# Out:
# 37828.820291124

# %%
auto_data['income']=auto_data['income'].replace(0,income_mean)
auto_data
# Out:
#       st gender             education  customer lifetime value        income  \
# 0     WA      U                Master              7977.057704  37828.820291
# 1     AZ      F              Bachelor              6979.535900  37828.820291
# 2     NV      F              Bachelor             12887.431700  48767.000000
# 3     CA      M              Bachelor              7645.861800  37828.820291
# 4     WA      M  High School or Below              5363.076500  36357.000000
# ...   ..    ...                   ...                      ...           ...
# 7065  CA      M              Bachelor             23405.987980  71941.000000
# 7066  CA      F               College              3096.511217  21604.000000
# 7067  CA      M              Bachelor              8163.890428  37828.820291
# 7068  CA      M               College              7524.442436  21941.000000
# 7069  CA      M               College              2611.836866  37828.820291
#
# ...

# %%
auto_data['total claim amount'].unique()
# Out:
# array([   2.704934, 1131.464935,  566.472247, ...,  541.282007,
#         198.234764,  790.784983])

# %%
#### Removing duplicates
auto_data=auto_data.drop_duplicates()
auto_data
# Out:
#       st gender             education  customer lifetime value        income  \
# 0     WA      U                Master              7977.057704  37828.820291
# 1     AZ      F              Bachelor              6979.535900  37828.820291
# 2     NV      F              Bachelor             12887.431700  48767.000000
# 3     CA      M              Bachelor              7645.861800  37828.820291
# 4     WA      M  High School or Below              5363.076500  36357.000000
# ...   ..    ...                   ...                      ...           ...
# 7065  CA      M              Bachelor             23405.987980  71941.000000
# 7066  CA      F               College              3096.511217  21604.000000
# 7067  CA      M              Bachelor              8163.890428  37828.820291
# 7068  CA      M               College              7524.442436  21941.000000
# 7069  CA      M               College              2611.836866  37828.820291
#
# ...

# %% [markdown]
# #### Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# %%
auto_data['st'].unique()
# Out:
# array(['WA', 'AZ', 'NV', 'CA', 'Oregon', 'Cali', nan], dtype=object)

# %%
auto_data['st']=auto_data['st'].replace(['AZ','WA','CA'],['Central','East','West'])
auto_data['st']=auto_data['st'].replace(['NV'],['Central'])
auto_data
# Out:
#            st gender             education  customer lifetime value  \
# 0        East      U                Master              7977.057704
# 1     Central      F              Bachelor              6979.535900
# 2     Central      F              Bachelor             12887.431700
# 3        West      M              Bachelor              7645.861800
# 4        East      M  High School or Below              5363.076500
# ...       ...    ...                   ...                      ...
# 7065     West      M              Bachelor             23405.987980
# 7066     West      F               College              3096.511217
# 7067     West      M              Bachelor              8163.890428
# 7068     West      M               College              7524.442436
# 7069     West      M               College              2611.836866
#
#             income  monthly premium auto number of open complaints  \
# 0     37828.820291                1000.0                         0
# ...

# %%
auto_data['st']=auto_data['st'].fillna(value="U")
auto_data
# Out:
#            st gender             education  customer lifetime value  \
# 0        East      U                Master              7977.057704
# 1     Central      F              Bachelor              6979.535900
# 2     Central      F              Bachelor             12887.431700
# 3        West      M              Bachelor              7645.861800
# 4        East      M  High School or Below              5363.076500
# ...       ...    ...                   ...                      ...
# 7065     West      M              Bachelor             23405.987980
# 7066     West      F               College              3096.511217
# 7067     West      M              Bachelor              8163.890428
# 7068     West      M               College              7524.442436
# 7069     West      M               College              2611.836866
#
#             income  monthly premium auto number of open complaints  \
# 0     37828.820291                1000.0                         0
# ...
